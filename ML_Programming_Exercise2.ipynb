# %%
import numpy as np
import matplotlib.pyplot as plt


random_array = np.random.random((1000,2))
x, y = random_array[:,0], random_array[:,1]
plt.scatter(x,y)
plt.show()

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

mu = np.array([0.0, 1.0])
sigma = np.array([[1, 0.25], [0.25, 1]])

# Our 2-dimensional distribution will be over variables X and Y
N = 100
X = np.linspace(-3, 3, N)
Y = np.linspace(-3, 4, N)
X, Y = np.meshgrid(X, Y)

# Pack X and Y into a single 3-dimensional array
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y

F = multivariate_normal(mu, sigma)
Z = F.pdf(pos)

fig = plt.figure(figsize = (15,15))
ax = plt.subplot(projection='3d')
ax.plot_surface(X, Y, Z, rstride=3, cstride=3, linewidth=1, antialiased=True,
                cmap=cm.viridis)

cset = ax.contourf(X, Y, Z, zdir='z', offset=-0.15, cmap=cm.viridis)


# Adjust the limits, ticks and view angle
ax.set_zlim(-0.15,0.2)
ax.view_init(27, -20)
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8p/nqs4s0kd4vg6qcsdncs_4t680000gn/T/ipykernel_7380/1859512040.py in <module>
#      16 pos[:, :, 1] = Y
#      17
# ---> 18 F = multivariate_normal(mu, sigma)
#      19 Z = F.pdf(pos)
#      20
#
# NameError: name 'multivariate_normal' is not defined
